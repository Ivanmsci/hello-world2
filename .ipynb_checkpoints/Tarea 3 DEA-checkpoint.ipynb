# %% [markdown]
# ## Tarea 3

# %%
import numpy as np

# importar matplotlib.pyplot

import matplotlib.pyplot as plt

# comando para que las gráficas salgan en la misma ventana}

# %matplotlib inline

# %%
#silicio

Eg01 = 1.17
beta1 = 636
alfa1 = 4.73*(10**-4)
def f_si(T):
    return Eg01 - (alfa1*(T**2))/(T + beta1)

#GaAs

Eg02 = 1.521
beta2 = 220
alfa2 = 5.58*(10**-4)
def f_GaAs(T):
    return Eg02 - (alfa2*(T**2))/(T + beta2)

#Ge

Eg03 = 0.74
beta3 = 235
alfa3 = 4.774*(10**-4)
def f_Ge(T):
    return Eg03 - (alfa3*(T**2))/(T + beta3)

# %%
Tnum = np.linspace(0,800,80)


ynum1 = f_si(Tnum)
ynum2 = f_GaAs(Tnum)
ynum3 = f_Ge(Tnum)

# Graficar


plt.figure(figsize=(15,8))

# Crear el tamaño de la figura a graficar
plt.plot(Tnum, ynum1, '--b', lw = 3, label = '$Silicio$')
plt.plot(Tnum, ynum2, '--p', lw = 3, label = '$GaAs$')
plt.plot(Tnum, ynum3, '--k', lw = 3, label = '$Ge$')


#Nombrar los ejes de la gráfica
plt.xlabel ('$T(K)$')
plt.ylabel('$Eg = Eg(0) - (alfa*T)/(beta + T) $')


#mostrar la cuadricula

plt.legend(loc = 'best')    #acomoda las eqtiquetas donde al programa le convenga XD

plt.grid()     #muestra la cuadricula

plt.show()     #muestra lo que se ha hecho

# %%
f_si(Tnum)
# Out:
# array([1.17      , 1.16992493, 1.16970435, 1.1693449 , 1.16885281,
#        1.16823395, 1.16749385, 1.16663772, 1.16567048, 1.16459676,
#        1.16342096, 1.16214722, 1.16077947, 1.15932144, 1.15777664,
#        1.15614843, 1.15443998, 1.1526543 , 1.15079427, 1.14886261,
#        1.14686191, 1.14479465, 1.14266318, 1.14046975, 1.1382165 ,
#        1.13590546, 1.1335386 , 1.13111778, 1.12864478, 1.12612131,
#        1.12354899, 1.12092939, 1.11826401, 1.11555428, 1.11280157,
#        1.11000721, 1.10717245, 1.10429852, 1.10138657, 1.09843772,
#        1.09545307, 1.09243363, 1.0893804 , 1.08629435, 1.0831764 ,
#        1.08002742, 1.07684829, 1.07363981, 1.07040279, 1.067138  ,
#        1.06384616, 1.060528  , 1.0571842 , 1.05381543, 1.05042232,
#        1.0470055 , 1.04356557, 1.04010309, 1.03661865, 1.03311277,
#        1.02958598, 1.02603878, 1.02247167, 1.01888512, 1.01527959,
#        1.01165553, 1.00801336, 1.00435352, 1.00067639, 0.99698238,
# ...

# %%
f_GaAs(Tnum)
# Out:
# array([1.521     , 1.52075135, 1.52004731, 1.51894315, 1.51748552,
#        1.51571409, 1.51366284, 1.51136097, 1.50883379, 1.50610329,
#        1.50318871, 1.5001069 , 1.49687276, 1.49349944, 1.48999863,
#        1.48638074, 1.48265508, 1.47883001, 1.47491303, 1.4709109 ,
#        1.46682976, 1.46267515, 1.45845211, 1.45416524, 1.44981871,
#        1.44541636, 1.4409617 , 1.43645795, 1.43190807, 1.42731479,
#        1.42268063, 1.4180079 , 1.41329878, 1.40855524, 1.40377915,
#        1.39897223, 1.39413607, 1.38927218, 1.38438194, 1.37946665,
#        1.37452754, 1.36956574, 1.36458232, 1.35957829, 1.35455458,
#        1.34951208, 1.34445162, 1.33937398, 1.33427991, 1.3291701 ,
#        1.32404521, 1.31890586, 1.31375264, 1.30858611, 1.30340679,
#        1.29821519, 1.29301177, 1.287797  , 1.28257129, 1.27733505,
#        1.27208867, 1.26683252, 1.26156694, 1.25629227, 1.25100884,
#        1.24571693, 1.24041685, 1.23510886, 1.22979324, 1.22447023,
# ...

# %%
f_Ge(Tnum)
# Out:
# array([0.74      , 0.73980028, 0.73923282, 0.73833971, 0.73715687,
#        0.73571511, 0.73404102, 0.73215768, 0.73008521, 0.72784122,
#        0.7254412 , 0.72289885, 0.7202263 , 0.71743432, 0.71453255,
#        0.71152961, 0.70843324, 0.70525042, 0.70198743, 0.69864998,
#        0.69524323, 0.69177189, 0.68824025, 0.68465221, 0.68101137,
#        0.67732101, 0.67358415, 0.66980357, 0.66598182, 0.66212128,
#        0.65822413, 0.6542924 , 0.65032797, 0.64633258, 0.64230785,
#        0.6382553 , 0.63417635, 0.63007229, 0.62594437, 0.62179373,
#        0.61762146, 0.61342856, 0.60921598, 0.60498462, 0.60073532,
#        0.59646885, 0.59218597, 0.58788738, 0.58357374, 0.57924567,
#        0.57490377, 0.57054859, 0.56618067, 0.56180051, 0.55740858,
#        0.55300533, 0.54859119, 0.54416658, 0.53973187, 0.53528744,
#        0.53083363, 0.52637078, 0.52189921, 0.51741922, 0.5129311 ,
#        0.50843514, 0.50393158, 0.49942068, 0.49490269, 0.49037784,
# ...
